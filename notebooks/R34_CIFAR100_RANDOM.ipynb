# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import sys

# %%
from pathlib import Path
sys.path.insert(0,os.path.abspath('../'))
sys.path.insert(0,os.path.abspath('../utilities'))

# %%
from utilities.resnet import resnet34

# %%
from utilities.utils import *

# %% [markdown]
# ## Resnet 34 on CIFAR-100

# %%
model = resnet34(num_classes=100)
#PRETRAINED_MODEL_PATH=os.path.join('/home/abc586/courseWork/introtodlsystem/finalProject/visualizing-vision-models/pretrained-models','resnet34_seed_566_epochs_100.pth')
#model.load_state_dict(torch.load(PRETRAINED_MODEL_PATH))

# %%
LABEL='R34-CIFAR100'
TYPE='RANDOM'

# %%
seed=672
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ## Getting the hooks for each layers

# %%
hookLayersActivationDict = {}
activationDict = {}

# %%
modelNamedModules = dict(model.named_modules())

# %%
hookLayers = []
for i in modelNamedModules.keys():
    if i.__contains__("bn") or i.__contains__("relu") or i.__contains__("avgpool") or i.__contains__("fc") or i.__contains__("maxpool") :
        hookLayers.append(i)

# %%
for layer in hookLayers:
    h = model.get_submodule(layer).register_forward_hook(getActivation(layer,hookLayersActivationDict))

# %% [markdown]
# ## CIFAR 100

# %%
TRAIN_BATCH_SIZE = 256
TEST_BATCH_SIZE = 256
NUM_WORKERS = 0

normalize = transforms.Normalize(mean=[0.5071, 0.4867, 0.4408],
                                     std=[0.2675, 0.2565, 0.2761])

train_dataset = datasets.CIFAR100(root='./data', train=True, transform=transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, 4),
            transforms.ToTensor(),
            normalize,
        ]), download=True)

train_loader = torch.utils.data.DataLoader(train_dataset,
        batch_size=TRAIN_BATCH_SIZE, shuffle=True,
        num_workers=NUM_WORKERS, pin_memory=True)

val_loader = torch.utils.data.DataLoader(
        datasets.CIFAR100(root='./data', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=TEST_BATCH_SIZE, shuffle=False,
        num_workers=NUM_WORKERS, pin_memory=True)
# Out:
# Files already downloaded and verified

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model = model.to(device)
valid_acc,activationDict = evaluate(model,device,val_loader,hookLayers,hookLayersActivationDict)
# Out:
# Iteration:   0%|          | 0/40 [00:01<?, ?it/s]

# %% [markdown]
# ## HSIC calculation and plots

# %%
col1,col2,hsicScoreList = getLayerWiseOutputCorrelation(hookLayers,hookLayers,activationDict,activationDict)
# Out:
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn2, HSIC score:4.602480203175219e-06
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn2, HSIC score:4.602480203175219e-06
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:layer2.2.bn2, HSIC score:4.602480203175219e-06
# ...
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer2.3.relu2, HSIC score:5.753565801569493e-07
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.0.bn1, HSIC score:0.002311128657311201
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.0.relu1, HSIC score:0.002311128657311201
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.0.bn2, HSIC score:0.027224447578191757
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.0.relu2, HSIC score:0.027224447578191757
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.1.bn1, HSIC score:0.0015708169667050242
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.1.relu1, HSIC score:0.0015708169667050242
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.1.bn2, HSIC score:1.1339104175567627
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.1.relu2, HSIC score:1.1339104175567627
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.2.bn1, HSIC score:0.38718295097351074
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.2.relu1, HSIC score:0.38718295097351074
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.2.bn2, HSIC score:4931331.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.2.relu2, HSIC score:4931331.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.3.bn1, HSIC score:6495742361337856.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.3.relu1, HSIC score:6495742361337856.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.3.bn2, HSIC score:5.696237691391059e+27
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.3.relu2, HSIC score:5.696237691391059e+27
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.4.bn1, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.4.relu1, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.4.bn2, HSIC score:3.1931436151731126e+19
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.4.relu2, HSIC score:3.1931436151731126e+19
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:avgpool, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:bn1, HSIC score:0.002904109889641404
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:relu, HSIC score:0.002904109889641404
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.0.bn1, HSIC score:0.002948980312794447
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.0.relu1, HSIC score:0.002948980312794447
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.0.bn2, HSIC score:0.0016587339341640472
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.0.relu2, HSIC score:0.0016587339341640472
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.1.bn1, HSIC score:0.0013965107500553131
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.1.relu1, HSIC score:0.0013965107500553131
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.1.bn2, HSIC score:0.00024054036475718021
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.1.relu2, HSIC score:0.00024054036475718021
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.2.bn1, HSIC score:0.0004039619234390557
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.2.relu1, HSIC score:0.0004039619234390557
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.2.bn2, HSIC score:6.612020115426276e-06
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer1.2.relu2, HSIC score:6.612020115426276e-06
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.0.bn1, HSIC score:0.0021211705170571804
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.0.relu1, HSIC score:0.0021211705170571804
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.0.bn2, HSIC score:0.0010847332887351513
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.0.relu2, HSIC score:0.0010847332887351513
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.1.bn1, HSIC score:0.000756006280425936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.1.relu1, HSIC score:0.000756006280425936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.1.bn2, HSIC score:0.00022010321845300496
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.1.relu2, HSIC score:0.00022010321845300496
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.2.bn1, HSIC score:0.0011923310812562704
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.2.relu1, HSIC score:0.0011923310812562704
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.2.bn2, HSIC score:4.602480203175219e-06
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.2.relu2, HSIC score:4.602480203175219e-06
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.3.bn1, HSIC score:9.44812418310903e-05
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.3.relu1, HSIC score:9.44812418310903e-05
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.3.bn2, HSIC score:5.753565801569493e-07
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer2.3.relu2, HSIC score:5.753565801569493e-07
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.0.bn1, HSIC score:0.002311128657311201
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.0.relu1, HSIC score:0.002311128657311201
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.0.bn2, HSIC score:0.027224447578191757
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.0.relu2, HSIC score:0.027224447578191757
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.1.bn1, HSIC score:0.0015708169667050242
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.1.relu1, HSIC score:0.0015708169667050242
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.1.bn2, HSIC score:1.1339104175567627
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.1.relu2, HSIC score:1.1339104175567627
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.2.bn1, HSIC score:0.38718295097351074
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.2.relu1, HSIC score:0.38718295097351074
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.2.bn2, HSIC score:4931331.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.2.relu2, HSIC score:4931331.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.3.bn1, HSIC score:6495742361337856.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.3.relu1, HSIC score:6495742361337856.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.3.bn2, HSIC score:5.696237691391059e+27
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.3.relu2, HSIC score:5.696237691391059e+27
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.4.bn1, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.4.relu1, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.4.bn2, HSIC score:3.1931436151731126e+19
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.4.relu2, HSIC score:3.1931436151731126e+19
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:avgpool, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:avgpool, HSIC score:inf
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer3.5.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer3.5.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.0.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.0.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan
# Layer 1:fc, HSIC score:3135.38525390625
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:inf
# Denom:nan

# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.ticker as ticker

# %%
hsicData = {
    'L1' : col1,
    'L2' : col2,
    'hsic':hsicScoreList
}

hsicDataFrame = pd.DataFrame(data=hsicData)
hsicDataFrame = hsicDataFrame.pivot("L1", "L2", "hsic")

# %%
plt.figure(figsize=(15,10))
ax = sns.heatmap(hsicDataFrame.T)
plt.xlabel("Layers "+LABEL,fontsize='36')
plt.ylabel("Layers "+LABEL,fontsize='36')
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xticks(ax.get_xticks()[::4])
ax.set_yticks(ax.get_yticks()[::4])
ax.invert_yaxis()
plt.savefig(LABEL+"_"+TYPE+'.pdf',fmt='pdf',bbox_inches='tight')
# Out:
# /tmp/ipykernel_1801452/3750928071.py:9: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "fmt" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig(LABEL+"_"+TYPE+'.pdf',fmt='pdf',bbox_inches='tight')
